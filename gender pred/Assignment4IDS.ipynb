# %%
import pandas as pd

# %%
ds = pd.read_csv("gen-pred.csv")
ds
# Out:
#     height  weight beard hair_length  shoe_size scarf eye_color  gender
# 0       71     176   yes       short         44    no     black    male
# 1       68     165    no        bald         41    no     black    male
# 2       62     132    no      medium         37   yes      blue  female
# 3       65     138    no        long         38    no      gray  female
# 4       70     197   yes      medium         43    no      gray    male
# ..     ...     ...   ...         ...        ...   ...       ...     ...
# 75      65      99    no       short         39   yes     green  female
# 76      61      98    no       short         37    no     brown  female
# 77      67     119   yes       short         40    no     black    male
# 78      70     190   yes      medium         43    no      gray    male
# 79      62     142   yes        long         37    no      blue  female
#
# [80 rows x 8 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

ds['beard']=le.fit_transform(ds['beard'])
ds['hair_length']=le.fit_transform(ds['hair_length'])
ds['scarf']=le.fit_transform(ds['scarf'])
ds['eye_color']=le.fit_transform(ds['eye_color'])
ds['gender']=le.fit_transform(ds['gender'])
ds
# Out:
#     height  weight  beard  hair_length  shoe_size  scarf  eye_color  gender
# 0       71     176      1            3         44      0          0       1
# 1       68     165      0            0         41      0          0       1
# 2       62     132      0            2         37      1          1       0
# 3       65     138      0            1         38      0          3       0
# 4       70     197      1            2         43      0          3       1
# ..     ...     ...    ...          ...        ...    ...        ...     ...
# 75      65      99      0            3         39      1          4       0
# 76      61      98      0            3         37      0          2       0
# 77      67     119      1            3         40      0          0       1
# 78      70     190      1            2         43      0          3       1
# 79      62     142      1            1         37      0          1       0
#
# [80 rows x 8 columns]

# %%
a = ds[['height','weight','beard','hair_length','shoe_size','scarf','eye_color']]
b = ds['gender']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.33,random_state=42)
X_train, X_test, y_train, y_test = train_test_split(a,b,test_size=0.20,random_state=30)

# %%
from sklearn.neural_network import MLPClassifier

clf = MLPClassifier(hidden_layer_sizes=(6,5),
                    random_state=5,
                    verbose=True,
                    learning_rate_init=0.01)


clf.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 5.55159290
# Iteration 2, loss = 3.33688202
# Iteration 3, loss = 1.47223972
# Iteration 4, loss = 0.77898396
# Iteration 5, loss = 0.83023799
# Iteration 6, loss = 0.83226776
# Iteration 7, loss = 0.82684168
# Iteration 8, loss = 0.82084641
# Iteration 9, loss = 0.81352283
# Iteration 10, loss = 0.80036899
# Iteration 11, loss = 0.77922033
# Iteration 12, loss = 0.75344153
# Iteration 13, loss = 0.72621921
# Iteration 14, loss = 0.70037701
# Iteration 15, loss = 0.67820911
# Iteration 16, loss = 0.66125733
# Iteration 17, loss = 0.65028308
# Iteration 18, loss = 0.64521656
# Iteration 19, loss = 0.64524670
# Iteration 20, loss = 0.64901773
# Iteration 21, loss = 0.65490340
# Iteration 22, loss = 0.66128723
# Iteration 23, loss = 0.66680178
# Iteration 24, loss = 0.67048442
# Iteration 25, loss = 0.67183786
# Iteration 26, loss = 0.67080781
# Iteration 27, loss = 0.66771471
# Iteration 28, loss = 0.66308067
# Iteration 29, loss = 0.65763132
# ...

# %%
y_pred=clf.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6875

# %%
from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,y_pred))

print(classification_report(y_test,y_pred))
# Out:
# [[2 5]
#  [0 9]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.29      0.44         7
#            1       0.64      1.00      0.78         9
#
#     accuracy                           0.69        16
#    macro avg       0.82      0.64      0.61        16
# weighted avg       0.80      0.69      0.63        16

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf=RandomForestClassifier(n_estimators=100)

rf_clf.fit(X_train,y_train)

random_y_pred=rf_clf.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,random_y_pred))

print(classification_report(y_test,random_y_pred))
# Out:
# [[7 0]
#  [0 9]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         9
#
#     accuracy                           1.00        16
#    macro avg       1.00      1.00      1.00        16
# weighted avg       1.00      1.00      1.00        16

# %%
from sklearn import svm
svm_clf = svm.SVC(kernel='linear') 
svm_clf.fit(X_train, y_train)
svm_pred = svm_clf.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,svm_pred))

print(classification_report(y_test,svm_pred))
# Out:
# [[7 0]
#  [1 8]]
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.93         7
#            1       1.00      0.89      0.94         9
#
#     accuracy                           0.94        16
#    macro avg       0.94      0.94      0.94        16
# weighted avg       0.95      0.94      0.94        16

# %%
ds2=ds.drop('weight', axis = 1, inplace = True)
ds2=ds.drop('beard', axis = 1, inplace = True)
print(ds)
# Out:
#     height  hair_length  shoe_size  scarf  eye_color  gender
# 0       71            3         44      0          0       1
# 1       68            0         41      0          0       1
# 2       62            2         37      1          1       0
# 3       65            1         38      0          3       0
# 4       70            2         43      0          3       1
# ..     ...          ...        ...    ...        ...     ...
# 75      65            3         39      1          4       0
# 76      61            3         37      0          2       0
# 77      67            3         40      0          0       1
# 78      70            2         43      0          3       1
# 79      62            1         37      0          1       0
#
# [80 rows x 6 columns]

# %%
x = ds[['height','hair_length','shoe_size','scarf','eye_color']]
y = ds['gender']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=42)

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(hidden_layer_sizes=(6,5),
                    random_state=5,
                    verbose=True,
                    learning_rate_init=0.01)


clf.fit(X_train,y_train)

ypred=clf.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test,ypred)

from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,ypred))

print(classification_report(y_test,ypred))
# Out:
# Iteration 1, loss = 2.14059145
# Iteration 2, loss = 1.76845084
# Iteration 3, loss = 1.43778079
# Iteration 4, loss = 1.15822924
# Iteration 5, loss = 0.94517806
# Iteration 6, loss = 0.80696025
# Iteration 7, loss = 0.73588020
# Iteration 8, loss = 0.68889796
# Iteration 9, loss = 0.68105369
# Iteration 10, loss = 0.68111180
# Iteration 11, loss = 0.68117090
# Iteration 12, loss = 0.68122931
# Iteration 13, loss = 0.68128582
# Iteration 14, loss = 0.68133962
# Iteration 15, loss = 0.68139013
# Iteration 16, loss = 0.68143697
# Iteration 17, loss = 0.68147994
# Iteration 18, loss = 0.68151890
# Iteration 19, loss = 0.68155384
# Iteration 20, loss = 0.68158479
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[0 7]
#  [0 9]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         7
#            1       0.56      1.00      0.72         9
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf_clf=RandomForestClassifier(n_estimators=100)
rf_clf.fit(X_train,y_train)

random_y_pred=rf_clf.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,random_y_pred))

print(classification_report(y_test,random_y_pred))
# Out:
# [[6 1]
#  [0 9]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92         7
#            1       0.90      1.00      0.95         9
#
#     accuracy                           0.94        16
#    macro avg       0.95      0.93      0.94        16
# weighted avg       0.94      0.94      0.94        16

# %%
from sklearn import svm
svm_clf = svm.SVC(kernel='linear') 
svm_clf.fit(X_train, y_train)
svm_pred = svm_clf.predict(X_test)

from sklearn.metrics import classification_report,confusion_matrix

print(confusion_matrix(y_test,svm_pred))

print(classification_report(y_test,svm_pred))
# Out:
# [[6 1]
#  [0 9]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92         7
#            1       0.90      1.00      0.95         9
#
#     accuracy                           0.94        16
#    macro avg       0.95      0.93      0.94        16
# weighted avg       0.94      0.94      0.94        16

# %%
ds3 = pd.read_csv("gen-pred.csv")

from sklearn import preprocessing
le = preprocessing.LabelEncoder()
ds3['beard']=le.fit_transform(ds3['beard'])
ds3['hair_length']=le.fit_transform(ds3['hair_length'])
ds3['scarf']=le.fit_transform(ds3['scarf'])
ds3['eye_color']=le.fit_transform(ds3['eye_color'])
ds3['gender']=le.fit_transform(ds3['gender'])
ds3

x = ds3[['height','weight','beard','hair_length','shoe_size','scarf','eye_color']]
y = ds3['gender']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.20,random_state=42)



df3
# Out:
#     height  weight  beard  hair_length  shoe_size  scarf  eye_color  gender
# 0       71     176      1            3         44      0          0       1
# 1       68     165      0            0         41      0          0       1
# 2       62     132      0            2         37      1          1       0
# 3       65     138      0            1         38      0          3       0
# 4       70     197      1            2         43      0          3       1
# ..     ...     ...    ...          ...        ...    ...        ...     ...
# 75      65      99      0            3         39      1          4       0
# 76      61      98      0            3         37      0          2       0
# 77      67     119      1            3         40      0          0       1
# 78      70     190      1            2         43      0          3       1
# 79      62     142      1            1         37      0          1       0
#
# [80 rows x 8 columns]

# %%
from sklearn.model_selection import ShuffleSplit,cross_val_score
from sklearn.tree import DecisionTreeClassifier

dt=DecisionTreeClassifier()
shuffle_split=ShuffleSplit(test_size=0.3,train_size=0.5,n_splits=10)

scores=cross_val_score(dt,x,y,scoring="f1",cv=shuffle_split)

print("cross Validation scores:n {}".format(scores))
print("Average Cross Validation score :{}".format(scores.mean()))
# Out:
# cross Validation scores:n [0.95652174 0.95652174 0.85714286 0.96774194 0.89655172 0.96
#  0.96296296 1.         1.         0.96551724]
# Average Cross Validation score :0.9522960199367801

# %%
from sklearn.model_selection import LeavePOut,cross_val_score
from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings('ignore')

lpo=LeavePOut(p=2)
lpo.get_n_splits(x)
tree=DecisionTreeClassifier(max_depth=5)
score=cross_val_score(tree,x,y,scoring="f1",cv=lpo)
print("Cross Validation Scores {}".format(score))
print("Avg Cross Validation score:{}".format(score.mean()))
# Out:
# Cross Validation Scores [1.         1.         1.         ... 1.         0.66666667 0.66666667]
# Avg Cross Validation score:0.7795358649789028

# %%
    ds_new_rows = pd.DataFrame(ds3)


new_row = [{'height':67,'weight':126,'beard':1,'hair_length':3,'shoe_size':42,"scarf":0,'eye_color':1,'gender':1},
           {'height':66,'weight':132,'beard':1,'hair_length':0,'shoe_size':42,"scarf":0,'eye_color':2,'gender':1},
           {'height':68,'weight':140,'beard':0,'hair_length':1,'shoe_size':40,"scarf":0,'eye_color':1,'gender':1},
           {'height':65,'weight':200,'beard':0,'hair_length':3,'shoe_size':42,"scarf":0,'eye_color':1,'gender':1},
           {'height':68,'weight':130,'beard':1,'hair_length':2,'shoe_size':40,"scarf":0,'eye_color':3,'gender':1}]             
ds_new_rows = ds_new_rows.append(new_row, ignore_index=True)

print('\n\nNew row added to DataFrame (ds)\n')
print(ds_new_rows)
# Out:
# New row added to DataFrame (ds)
#
#     height  weight  beard  hair_length  shoe_size  scarf  eye_color  gender
# 0       71     176      1            3         44      0          0       1
# 1       68     165      0            0         41      0          0       1
# 2       62     132      0            2         37      1          1       0
# 3       65     138      0            1         38      0          3       0
# 4       70     197      1            2         43      0          3       1
# ..     ...     ...    ...          ...        ...    ...        ...     ...
# 80      67     126      1            3         42      0          1       1
# 81      66     132      1            0         42      0          2       1
# 82      68     140      0            1         40      0          1       1
# 83      65     200      0            3         42      0          1       1
# 84      68     130      1            2         40      0          3       1
#
# [85 rows x 8 columns]

# %%
a = ds_new_rows[['height','weight','beard','hair_length','shoe_size','scarf','eye_color']]
b = ds_new_rows['gender']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(a,b,test_size=0.20,random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
nbclassifier = GaussianNB()
nbclassifier.fit(X_train,y_train)

Y_predicts= nbclassifier.predict(X_test)
Y_predicts

from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,Y_predicts))

print(classification_report(y_test,Y_predicts))
# Out:
# [[ 6  1]
#  [ 0 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.92         7
#            1       0.91      1.00      0.95        10
#
#     accuracy                           0.94        17
#    macro avg       0.95      0.93      0.94        17
# weighted avg       0.95      0.94      0.94        17
