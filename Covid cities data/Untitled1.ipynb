# %%
import folium
import pandas as pd
pakistan_map = folium.Map(location = [30.37,69.34], zoom_start=4.5, tiles='OpenStreetMap')
import csv

# from google.colab import drive
# drive.mount('/content/drive')

df = pd.read_csv(r'/content/citiesdata.csv')
df

t = 0
for c in df['Total Cases']:
  t = int(c) + int(t)
for state,lat,long,tc,de,re,ac in zip(list(df['City']),list(df['Latitude']),list(df['Longitude']),list(df['Total Cases']),list(df['Deaths']),list(df['Recoveries']),list(df['Active Cases'])):
    folium.CircleMarker(location = [lat,long],radius = (tc/t)*100,color = 'red',fill = False,fill_color = 'blue').add_to(pakistan_map)
    xyz = '<strong>City:  ' + state + '</strong><br>' + 'Total Cases: ' + str(tc) + '<br>' + 'Deaths: '+ str(de) + '<br>' + 'Recoveries: ' + str(re) + '<br>' + 'Active Cases: ' + str(ac)
    iframe = folium.IFrame(xyz, width=200, height=150)
    popupData = folium.Popup(iframe, max_width=500)
    folium.Marker(location = [lat,long], popup=popupData).add_to(pakistan_map)
    

pakistan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c553fff4d2741e473490c04f65db11ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c553fff4d2741e473490c04f65db11ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c553fff4d2741e473490c04f65db11ff = L.map(
#                 &quot;map_c553fff4d2741e473490c04f65db11ff&quot;,
#                 {
#                     center: [30.37, 69.34],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5983df6297ffc75f74a79c8d35fb5731 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c553fff4d2741e473490c04f65db11ff);
#
#
#             var circle_marker_744141ae7ae1213fdf780144ce4465e3 = L.circleMarker(
#                 [31.5204, 74.3587],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 23.696682464454977, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c553fff4d2741e473490c04f65db11ff);
#
#
#             var marker_51afd15c39e525f7d054e2df0707f7da = L.marker(
#                 [31.5204, 74.3587],
#                 {}
#             ).addTo(map_c553fff4d2741e473490c04f65db11ff);
#
#
#         var popup_42302611945880dae0ebd755af28964d = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_f847494c15785b56b87007fff0a084f7 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkNpdHk6ICBMYWhvcmU8L3N0cm9uZz48YnI+VG90YWwgQ2FzZXM6IDI1MDA8YnI+RGVhdGhzOiA5MDA8YnI+UmVjb3ZlcmllczogMTYwMDxicj5BY3RpdmUgQ2FzZXM6IDM1MA==&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_42302611945880dae0ebd755af28964d.setContent(i_frame_f847494c15785b56b87007fff0a084f7);
#
#
#         marker_51afd15c39e525f7d054e2df0707f7da.bindPopup(popup_42302611945880dae0ebd755af28964d)
#         ;
#
#
#
#
#             var circle_marker_79048e08e2bed5406e90accc31f86095 = L.circleMarker(
#                 [33.5651, 73.0169],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 14.218009478672986, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c553fff4d2741e473490c04f65db11ff);
#
#
#             var marker_a6a6bd31c21073f1484ce636a5b70f53 = L.marker(
#                 [33.5651, 73.0169],
#                 {}
#             ).addTo(map_c553fff4d2741e473490c04f65db11ff);
#
#
#         var popup_efa113387738a47230806a6f52b938df = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_1c23c3a836db9c9ba1f540dd6b8dc3b4 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8c3Ryb25nPkNpdHk6ICBSYXdhbHBpbmRpPC9zdHJvbmc+PGJyPlRvdGFsIENhc2VzOiAxNTAwPGJyPkRlYXRoczogNTAwPGJyPlJlY292ZXJpZXM6IDEwMDA8YnI+QWN0aXZlIENhc2VzOiAyMjI=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#             popup_efa113387738a47230806a6f52b938df.setContent(i_frame_1c23c3a836db9c9ba1f540dd6b8dc3b4);
#
#
#         marker_a6a6bd31c21073f1484ce636a5b70f53.bindPopup(popup_efa113387738a47230806a6f52b938df)
#         ;
#
#
#
#
#             var circle_marker_d2e9aa182c2a73344c4f16edf72fdc20 = L.circleMarker(
#                 [30.1575, 71.5249],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.530805687203792, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c553fff4d2741e473490c04f65db11ff);
#
#
#             var marker_5d5ec93d9785ebfaf34fc012f653ea3e = L.marker(
#                 [30.1575, 71.5249],
#                 {}
#             ).addTo(map_c553fff4d2741e473490c04f65db11ff);
#
#
#         var popup_802cfdb4675727d4bc37f21586014a2e = L.popup({&quot;maxWidth&quot;: 500});
#
#
#             var i_frame_46f19e001e694b51e972

# %%
pwd
# Out:
# '/content'
